# %%
from collections import Counter
from imblearn.over_sampling import SMOTE
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 from collections import Counter
# ----> 2 from imblearn.over_sampling import SMOTE
#
# File ~\AppData\Roaming\Python\Python313\site-packages\imblearn\__init__.py:54
#      50     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      51     # We are not importing the rest of scikit-learn during the build
#      52     # process, as it may not be compiled yet
#      53 else:
# ---> 54     from . import (
#      55         combine,
#      56         ensemble,
#      57         exceptions,
#      58         metrics,
#      59         model_selection,
#      60         over_sampling,
#      61         pipeline,
#      62         tensorflow,
#      63         under_sampling,
#      64         utils,
#      65     )
#      66     from ._version import __version__
# ...
